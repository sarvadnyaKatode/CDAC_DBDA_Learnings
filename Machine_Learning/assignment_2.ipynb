# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel('/content/Sarvadnya Katode - SLRAssignment1.xlsx')
df
# Out:
#      X      y
# 0  100  212.0
# 1  105  221.0
# 2  110  230.0
# 3   82  179.6
# 4   76  168.8
# 5   45  113.0
# 6  -10   14.0
# 7  -50  -58.0
# 8 -100 -148.0

# %%
corr_matrix = df.corr()
print(corr_matrix)
# Out:
#      X    y
# X  1.0  1.0
# y  1.0  1.0

# %%
df.describe()
# Out:
#                 X           y
# count    9.000000    9.000000
# mean    39.777778  103.600000
# std     75.836630  136.505934
# min   -100.000000 -148.000000
# 25%    -10.000000   14.000000
# 50%     76.000000  168.800000
# 75%    100.000000  212.000000
# max    110.000000  230.000000

# %%
x = df.iloc[:,0]
y = df.iloc[:,1]

# %%
plt.scatter(x,y)
plt.show()

# %%
import sklearn
from sklearn.linear_model import LinearRegression

# %%
X = df[["X"]]
y = df["y"]

# %%
model = LinearRegression()
model.fit(X,y)

yhat = model.predict(X)

# %%
model.score(X,y)
# Out:
# 1.0

# %%
coef = model.coef_[0]
intercept = model.intercept_

coef, intercept
# Out:
# (np.float64(1.7999999999999996), np.float64(32.00000000000003))

# %%
test_values = pd.DataFrame({"X": [0, 50, 100, -50]})
predictions = model.predict(test_values)
test_values["Predicted_y"] = predictions

test_values
# Out:
#      X  Predicted_y
# 0    0         32.0
# 1   50        122.0
# 2  100        212.0
# 3  -50        -58.0
